# %% [markdown]
# # Top Earners in the Movie Industry
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > I chose the IMDB movie dataset. I've wanted to know how much the different movie genres, directors and production companies have grossed over a period of time.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imdb-movies.csv')

# %%
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                  director                                     genres  \
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 1           George Miller  Action|Adventure|Science Fiction|Thriller
# 2        Robert Schwentke         Adventure|Science Fiction|Thriller
# 3             J.J. Abrams   Action|Adventure|Science Fiction|Fantasy
# 4               James Wan                      Action|Crime|Thriller
# ...                   ...                                        ...
# 10861         Bruce Brown                                Documentary
# 10862  John Frankenheimer                     Action|Adventure|Drama
# 10863      Eldar Ryazanov                             Mystery|Comedy
# 10864         Woody Allen                              Action|Comedy
# 10865    Harold P. Warren                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...       6/9/15
# 1      Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15
# 2      Summit Entertainment|Mandeville Films|Red Wago...      3/18/15
# 3              Lucasfilm|Truenorth Productions|Bad Robot     12/15/15
# 4      Universal Pictures|Original Film|Media Rights ...       4/1/15
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films      6/15/66
# 10862  Cherokee Productions|Joel Productions|Douglas ...     12/21/66
# 10863                                            Mosfilm       1/1/66
# 10864                            Benedict Pictures Corp.      11/2/66
# 10865                                          Norm-Iris     11/15/66
#
#        release_year
# 0              2015
# 1              2015
# 2              2015
# 3              2015
# 4              2015
# ...             ...
# 10861          1966
# 10862          1966
# 10863          1966
# 10864          1966
# 10865          1966
#
# [10866 rows x 9 columns]

# %% [markdown]
# ### Data Cleaning

# %%
# Drop columns without neccesary information and remove all records with no financial information

# %%
df.isna().any()
# Out:
# popularity              False
# budget                  False
# revenue                 False
# original_title          False
# director                False
# genres                  False
# production_companies    False
# release_date            False
# release_year            False
# dtype: bool

# %%
#I did these steps in excel

df.columns
# Out:
# Index(['popularity', 'budget', 'revenue', 'original_title', 'director',
#        'genres', 'production_companies', 'release_date', 'release_year'],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.drop(['release_date'], axis='columns', inplace=True)
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0       32.985763  150000000  1513528810                Jurassic World
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                  director                                     genres  \
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 1           George Miller  Action|Adventure|Science Fiction|Thriller
# 2        Robert Schwentke         Adventure|Science Fiction|Thriller
# 3             J.J. Abrams   Action|Adventure|Science Fiction|Fantasy
# 4               James Wan                      Action|Crime|Thriller
# ...                   ...                                        ...
# 10861         Bruce Brown                                Documentary
# 10862  John Frankenheimer                     Action|Adventure|Drama
# 10863      Eldar Ryazanov                             Mystery|Comedy
# 10864         Woody Allen                              Action|Comedy
# 10865    Harold P. Warren                                     Horror
#
#                                     production_companies  release_year
# 0      Universal Studios|Amblin Entertainment|Legenda...          2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...          2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...          2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot          2015
# 4      Universal Pictures|Original Film|Media Rights ...          2015
# ...                                                  ...           ...
# 10861                                  Bruce Brown Films          1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...          1966
# 10863                                            Mosfilm          1966
# 10864                            Benedict Pictures Corp.          1966
# 10865                                          Norm-Iris          1966
#
# [9806 rows x 8 columns]

# %%
df=df.astype({'release_date': 'datetime64'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9806 entries, 0 to 10865
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            9806 non-null   float64
#  1   budget                9806 non-null   int64
#  2   revenue               9806 non-null   int64
#  3   original_title        9806 non-null   object
#  4   director              9806 non-null   object
#  5   genres                9806 non-null   object
#  6   production_companies  9806 non-null   object
#  7   release_date          9806 non-null   datetime64[ns]
#  8   release_year          9806 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 766.1+ KB

# %% [markdown]
# #### If I created one record for each the `production_companies` a movie was release under and one record each for `genres`<br>and tried to run calculations, it wouldn't work because for many records, the amount of `production_companies`<br>and `genres` aren't the same, so I'll create 2 dataframes; one w/o a `production_companies` column and one w/o a `genres` columns

# %% [markdown]
# #### One `production_companies` per record

# %%
multiple_production_companies = df.assign(production_companies=df.production_companies.str.split("|")).explode('production_companies')
multiple_production_companies
# Out:
#        popularity     budget     revenue            original_title  \
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# ...           ...        ...         ...                       ...
# 10862    0.065543          0           0                Grand Prix
# 10862    0.065543          0           0                Grand Prix
# 10863    0.065141          0           0       Beregis Avtomobilya
# 10864    0.064317          0           0    What's Up, Tiger Lily?
# 10865    0.035919      19000           0  Manos: The Hands of Fate
#
#                  director                                     genres  \
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# ...                   ...                                        ...
# 10862  John Frankenheimer                     Action|Adventure|Drama
# 10862  John Frankenheimer                     Action|Adventure|Drama
# 10863      Eldar Ryazanov                             Mystery|Comedy
# 10864         Woody Allen                              Action|Comedy
# 10865    Harold P. Warren                                     Horror
#
#               production_companies  release_year
# 0                Universal Studios          2015
# 0             Amblin Entertainment          2015
# 0               Legendary Pictures          2015
# 0          Fuji Television Network          2015
# 0                           Dentsu          2015
# ...                            ...           ...
# 10862             Joel Productions          1966
# 10862  Douglas & Lewis Productions          1966
# 10863                      Mosfilm          1966
# 10864      Benedict Pictures Corp.          1966
# 10865                    Norm-Iris          1966
#
# [23192 rows x 8 columns]

# %%
multiple_production_companies.drop(['genres'], axis='columns', inplace=True)
multiple_production_companies
# Out:
#        popularity     budget     revenue            original_title  \
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# ...           ...        ...         ...                       ...
# 10862    0.065543          0           0                Grand Prix
# 10862    0.065543          0           0                Grand Prix
# 10863    0.065141          0           0       Beregis Avtomobilya
# 10864    0.064317          0           0    What's Up, Tiger Lily?
# 10865    0.035919      19000           0  Manos: The Hands of Fate
#
#                  director         production_companies  release_year
# 0         Colin Trevorrow            Universal Studios          2015
# 0         Colin Trevorrow         Amblin Entertainment          2015
# 0         Colin Trevorrow           Legendary Pictures          2015
# 0         Colin Trevorrow      Fuji Television Network          2015
# 0         Colin Trevorrow                       Dentsu          2015
# ...                   ...                          ...           ...
# 10862  John Frankenheimer             Joel Productions          1966
# 10862  John Frankenheimer  Douglas & Lewis Productions          1966
# 10863      Eldar Ryazanov                      Mosfilm          1966
# 10864         Woody Allen      Benedict Pictures Corp.          1966
# 10865    Harold P. Warren                    Norm-Iris          1966
#
# [23192 rows x 7 columns]

# %%
multiple_production_companies.where(multiple_production_companies.release_year > 2005).production_companies.value_counts().head(10)
# Out:
# Universal Pictures                        149
# Warner Bros.                              131
# Relativity Media                          108
# Columbia Pictures                         100
# Paramount Pictures                         92
# Walt Disney Pictures                       79
# Twentieth Century Fox Film Corporation     79
# New Line Cinema                            71
# BBC Films                                  67
# Lionsgate                                  58
# Name: production_companies, dtype: int64

# %%
# GENRES
# For every string of genres in that record, split the production companies into a list. 
# This way we should be able to query whichever production company

# %%
genresdf = df.assign(genres=df.genres.str.split("|")).explode('genres')
genresdf
# Out:
#        popularity     budget     revenue            original_title  \
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 1       28.419936  150000000   378436354        Mad Max: Fury Road
# ...           ...        ...         ...                       ...
# 10863    0.065141          0           0       Beregis Avtomobilya
# 10863    0.065141          0           0       Beregis Avtomobilya
# 10864    0.064317          0           0    What's Up, Tiger Lily?
# 10864    0.064317          0           0    What's Up, Tiger Lily?
# 10865    0.035919      19000           0  Manos: The Hands of Fate
#
#                director           genres  \
# 0       Colin Trevorrow           Action
# 0       Colin Trevorrow        Adventure
# 0       Colin Trevorrow  Science Fiction
# 0       Colin Trevorrow         Thriller
# 1         George Miller           Action
# ...                 ...              ...
# 10863    Eldar Ryazanov          Mystery
# 10863    Eldar Ryazanov           Comedy
# 10864       Woody Allen           Action
# 10864       Woody Allen           Comedy
# 10865  Harold P. Warren           Horror
#
#                                     production_companies  release_year
# 0      Universal Studios|Amblin Entertainment|Legenda...          2015
# 0      Universal Studios|Amblin Entertainment|Legenda...          2015
# 0      Universal Studios|Amblin Entertainment|Legenda...          2015
# 0      Universal Studios|Amblin Entertainment|Legenda...          2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...          2015
# ...                                                  ...           ...
# 10863                                            Mosfilm          1966
# 10863                                            Mosfilm          1966
# 10864                            Benedict Pictures Corp.          1966
# 10864                            Benedict Pictures Corp.          1966
# 10865                                          Norm-Iris          1966
#
# [24712 rows x 8 columns]

# %%
genresdf.drop(['production_companies'], axis='columns', inplace=True)
genresdf
# Out:
#        popularity     budget     revenue            original_title  \
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 0       32.985763  150000000  1513528810            Jurassic World
# 1       28.419936  150000000   378436354        Mad Max: Fury Road
# ...           ...        ...         ...                       ...
# 10863    0.065141          0           0       Beregis Avtomobilya
# 10863    0.065141          0           0       Beregis Avtomobilya
# 10864    0.064317          0           0    What's Up, Tiger Lily?
# 10864    0.064317          0           0    What's Up, Tiger Lily?
# 10865    0.035919      19000           0  Manos: The Hands of Fate
#
#                director           genres  release_year
# 0       Colin Trevorrow           Action          2015
# 0       Colin Trevorrow        Adventure          2015
# 0       Colin Trevorrow  Science Fiction          2015
# 0       Colin Trevorrow         Thriller          2015
# 1         George Miller           Action          2015
# ...                 ...              ...           ...
# 10863    Eldar Ryazanov          Mystery          1966
# 10863    Eldar Ryazanov           Comedy          1966
# 10864       Woody Allen           Action          1966
# 10864       Woody Allen           Comedy          1966
# 10865  Harold P. Warren           Horror          1966
#
# [24712 rows x 7 columns]

# %% [markdown]
# #### One `genres` per record

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %% [markdown]
# ### Which production companies released the most movies in the last 10 years? Display the top 10 production companies.

# %%
multiple_production_companies.where(multiple_production_companies.release_year > 2005).production_companies.value_counts().head(10)
# Out:
# Universal Pictures                        149
# Warner Bros.                              131
# Relativity Media                          108
# Columbia Pictures                         100
# Paramount Pictures                         92
# Walt Disney Pictures                       79
# Twentieth Century Fox Film Corporation     79
# New Line Cinema                            71
# BBC Films                                  67
# Lionsgate                                  58
# Name: production_companies, dtype: int64

# %% [markdown]
# ### What 5 movie genres grossed the highest all-time?

# %%
genresdf.groupby('genres').revenue.sum().sort_values(ascending=False).head()
# Out:
# genres
# Action       173417346979
# Adventure    166317625752
# Comedy       142141376544
# Drama        138895805395
# Thriller     121188594087
# Name: revenue, dtype: int64

# %% [markdown]
# ### Who are the top 10 grossing directors?

# %%
df.groupby('director').revenue.sum().sort_values(ascending=False).head(10)
# Out:
# director
# Steven Spielberg     9018563772
# Peter Jackson        6523244659
# James Cameron        5841894863
# Michael Bay          4917208171
# Christopher Nolan    4167548502
# David Yates          4154295625
# Robert Zemeckis      3869690869
# Chris Columbus       3851491668
# Tim Burton           3665414624
# Ridley Scott         3649996480
# Name: revenue, dtype: int64

# %% [markdown]
# ### Compare the revenue of the highest grossing movies of all time.

# %%
df.groupby('original_title').revenue.sum().sort_values(ascending=False).head(10)
# Out:
# original_title
# Avatar                                          2781505847
# Star Wars: The Force Awakens                    2068178225
# Titanic                                         1845034188
# The Avengers                                    1568080742
# Jurassic World                                  1513528810
# Furious 7                                       1506249360
# Avengers: Age of Ultron                         1405035767
# Harry Potter and the Deathly Hallows: Part 2    1327817822
# Frozen                                          1277284869
# Iron Man 3                                      1215439994
# Name: revenue, dtype: int64

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# * Avatar is the highest-grossing movie of all time.
#
# * Steven Spielberg is the highest-grossing director of all time.
#
# * Action movies (not to my surprise) are the highest-grossing movies..
#
# * Disney is not one of the top 5 highest-grossing production companies during the last 10 years.
